# %% [markdown]
# <a href="https://colab.research.google.com/github/LaniW/Turtle/blob/main/Turtle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Turtle Graphics 🐢
# Lani Wang

# %% [markdown]
# 1/4/2024 \\
# I wanted to learn Turtle Graphics so the following is a Google Colab on that. \\
# This follows [Real Python's beginner's guide to Python Turtle](https://realpython.com/beginners-guide-python-turtle/)

# %%
#Installations
# !pip install ColabTurtle

# %%
import ColabTurtle.Turtle as honu
honu.initializeTurtle()
honu.right(90) #honu.rt()
honu.forward(100) #honu.fd()
honu.left(90) #honu.lt()
honu.backward(100) #honu.bk()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="500.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="500.0" y1="250.0" x2="500.0" y2="350.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,500.0,350.0) translate(482.0, 332.0)">
# ...

# %% [markdown]
# NOTE THAT THIS IS FOR THE ORIGNAL LIBRARY, NOT COLABTURTLE
#
# ![Coordinate System](data:image/png;base64,...)![Coordinate System]()

# %%
#Honu Tests the Coordinate System.
honu.home()
honu.goto(100,100)
honu.goto(100,50)
honu.goto(50,50)
honu.goto(50,100)

#Honu makes a Square!
honu.home()
for i in range(4):
  honu.fd(100)
  honu.rt(90)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
#Honu Changes the Background.
#honu.circle(60) A COMMAND THAT EXISTS IN TURTLE BUT NOT COLABTURTLE
#honu.dot(20) A COMMAND THAT EXISTS IN TURTLE BUT NOT COLABTURTLE
honu.bgcolor("red")
honu.bgcolor("green")
honu.bgcolor("blue")
#honu.title("Honu's Program") A COMMAND THAT EXISTS IN TURTLE BUT NOT COLABTURTLE
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="blue"/>
# ...

# %%
#Honu Becomes a Green Circle :,(
honu.initializeTurtle()
honu.shape("circle")
honu.pensize(4)
honu.fd(100)

honu.pencolor("green")
#honu.color("white", "green") A COMMAND THAT EXISTS IN TURTLE BUT NOT COLABTURTLE
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#
#       <g visibility=visible transform="rotate(180,400.0,150.0) translate(400.0, 150.0)">
#         <circle stroke="green" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:green;stroke:green;stroke-width:2"/>
#       </g>
#
#       </svg>

# %%
honu.initializeTurtle()
#honu.begin_fill() A COMMAND THAT EXISTS IN TURTLE BUT NOT COLABTURTLE
honu.fd(100)
honu.lt(120)
honu.fd(100)
honu.lt(120)
honu.fd(100)
#honu.end_fill() A COMMAND THAT EXISTS IN TURTLE BUT NOT COLABTURTLE

#Honu becomes speedy.
honu.speed(1)
honu.fd(100)
honu.speed(10)
honu.fd(100)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="150.0" x2="313.397" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="313.397" y1="200.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="250.0" x2="486.603" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="486.603" y1="300.0" x2="573.206" y2="350.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(120,573.206,350.0) translate(555.206, 332.0)">
# ...

# %%
honu.initializeTurtle()
#honu.pen(pencolor="purple", fillcolor="orange", pensize=10, speed=9) A COMMAND THAT EXISTS IN TURTLE BUT NOT COLABTURTLE

#Honu loses and gets back some pen ink.
honu.fd(100)
honu.rt(90)
honu.penup()
honu.fd(100)
honu.rt(90)
honu.pendown()
honu.fd(100)
honu.rt(90)
honu.penup()
honu.fd(100)
honu.pendown()
#honu.undo() A COMMAND THAT EXISTS IN TURTLE BUT NOT COLABTURTLE
honu.clear()
#honu.reset() A COMMAND THAT EXISTS IN TURTLE BUT NOT COLABTURTLE
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=visible transform="rotate(270,400.0,250.0) translate(382.0, 232.0)">
# ...

# %%
#honu.stamp() A COMMAND THAT EXISTS IN TURTLE BUT NOT COLABTURTLE
#honu.clearstamp(8) A COMMAND THAT EXISTS IN TURTLE BUT NOT COLABTURTLE
#hatchling = honu.clone() A COMMAND THAT EXISTS IN TURTLE BUT NOT COLABTURTLE

#Honu Goes in a Very Long Square Path.
honu.initializeTurtle()
n = 1
while n <= 40:
  honu.fd(100)
  honu.rt(90)
  n += 1
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...
